# %% [markdown]
# # Global settings

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

NB_COLUMN          = 5
NB_ROWS_PRIORITY   = 10
NB_ROWS_DATA       = 30

# %% [markdown]
# # Create the priority table

# %%
dic_priority = {}
for i in range(NB_COLUMN):
    dic_priority[f'Column_{i}'] = np.random.choice([0, 1], size=(NB_ROWS_PRIORITY,), p=[.5, .5])
dic_priority['Output'] = np.random.randint(99999, size=NB_ROWS_PRIORITY)

df_priority = pd.DataFrame(dic_priority)
df_priority.to_csv('data/priority.csv')

df_priority
# Out:
#    Column_0  Column_1  Column_2  Column_3  Column_4  Output
# 0         0         0         1         1         0   45758
# 1         1         1         0         0         0   72409
# 2         1         1         0         0         0   71211
# 3         1         0         0         1         1   65697
# 4         0         0         0         1         0   37065
# 5         0         0         1         1         1   92093
# 6         0         0         0         0         0   99299
# 7         1         1         1         0         1   32606
# 8         1         0         1         1         1   11534
# 9         1         0         0         0         0   94663

# %% [markdown]
# ## Create the data to map with an output column

# %%
data_row_list = []
for _ in range(NB_ROWS_DATA):
    # Select a random row of priority
    i = np.random.randint(NB_ROWS_PRIORITY)
    row = df_priority.iloc[i]

    # Transform the rwo to remove the X
    for i in range(NB_COLUMN):
        if row[f'Column_{i}'] == 'X':
            row[f'Column_{i}'] = np.random.randint(2)

    # Set the the corresponding line in priority
    data_row_list.append(row)
df_data = pd.DataFrame(data_row_list, columns=df_priority.columns)
df_data.index.names = ['Expected priority correspondance']
df_data.rename({'Output': 'Expected Output'})
df_data.to_csv('data/data.csv')

df_data
# Out:
#                                   Column_0  Column_1  Column_2  Column_3  \
# Expected priority correspondance
# 6                                        0         0         0         0
# 8                                        1         0         1         1
# 7                                        1         1         1         0
# 4                                        0         0         0         1
# 1                                        1         1         0         0
# 4                                        0         0         0         1
# 7                                        1         1         1         0
# 9                                        1         0         0         0
# 8                                        1         0         1         1
# 8                                        1         0         1         1
# 0                                        0         0         1         1
# ...

# %% [markdown]
# #
